# %%
# %load_ext sql
from sqlalchemy import create_engine
import pandas
# %sql postgresql://acserver@localhost/fact
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %%sql
# --select * from tracks_track
# select tracks_track.title, tracks_track.id, count(*)
#   from cars_laptime left join tracks_track on cars_laptime.track_id = tracks_track.id
#   group by tracks_track.title, tracks_track.id order by 3 desc;
# Out:
#  * postgresql://acserver@localhost/fact
# 29 rows affected.
# [('Magione', 33, 98),
#  ('Imola', 31, 91),
#  ('Spa', 61, 87),
#  ('Mugello', 38, 86),
#  ('Laguna Seca', 32, 85),
#  ('Monza', 34, 83),
#  ('Zandvoort', 68, 82),
#  ('Highlands Short', 30, 74),
#  ('Red Bull Ring GP', 53, 71),
#  ('Vallelunga', 64, 69),
#  ('Vallelunga - Club', 66, 66),
#  ('Nurburgring - GP', 45, 63),
#  ('Silverstone GP', 60, 59),
#  ('Silverstone - National', 58, 58),
#  ('Silverstone - International', 57, 55),
#  ('Nurburgring - GP (GT)', 46, 53),
#  ('Highlands', 27, 49),
#  ('Vallelunga - Classic', 65, 41),
#  ('Red Bull Ring National', 54, 37),
#  ('Highlands Long', 29, 34),
#  ('Nurburgring - Sprint (GT)', 48, 27),
#  ('Nurburgring - Sprint', 47, 25),
#  ('Okayama Grand Prix', 49, 20),
#  ('Tor Pozna?', 62, 20),
#  ('Donington Park GP', 17, 19),
#  ('Donington Park National', 18, 16),
#  ('Black Cat County', 9, 5),
#  ('Riverside Long', 55, 3),
#  ('Highlands Drift', 28, 1)]

# %%
# %%sql
# select title
#   from cars_car left join cars_laptime on cars_car.id=cars_laptime.car_id where track_id=33
# Out:
#  * postgresql://acserver@localhost/fact
# 98 rows affected.
# [('Ferrari GTO',),
#  ('Pagani Huayra BC',),
#  ('Audi S1',),
#  ('Audi Sport quattro S1 E2',),
#  ('McLaren MP4-12C',),
#  ('Porsche Cayenne Turbo S',),
#  ('Nissan 370z Nismo',),
#  ('Lamborghini Sesto Elemento',),
#  ('Porsche 911 GT3 R 2016',),
#  ('Alfa Romeo 33 Stradale',),
#  ('Shelby Cobra 427 S/C',),
#  ('Lotus Exige Scura',),
#  ('BMW M3 E30 Step1',),
#  ('Mercedes-Benz AMG GT3',),
#  ('BMW Z4 E89',),
#  ('Porsche 911 GT3 Cup 2017',),
#  ('Mazda 787B',),
#  ('Maserati 250F 12 cylinder',),
#  ('Porsche 911 GT1-98',),
#  ('Mercedes SLS AMG GT3',),
#  ('Abarth 595 SS Step 2',),
#  ('BMW 1M Stage 3',),
#  ('Alfa Romeo Mito QV',),
#  ('Porsche 718 Cayman S',),
#  ('BMW M3 GT2',),
#  ('Lotus 2-Eleven',),
#  ('BMW M3 E30 Gr.A 92',),
#  ('Giulietta QV',),
#  ('Ferrari 458 Italia Stage 3',),
#  ('BMW M3 E92',),
#  ('Lotus Exige S',),
#  ('Maserati Alfieri',),
#  ('Audi Sport quattro Step1',),
#  ('BMW M3 E30 Drift',),
# ...

# %%
df = result.DataFrame()
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
# ...
